# %% [markdown]
# <a href="https://colab.research.google.com/github/DuckMinKim/Python/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open('/content/drive/My Drive/Datas/thelittleprince.txt')
file
# Out:
# <_io.TextIOWrapper name='/content/drive/My Drive/Datas/thelittleprince.txt' mode='r' encoding='UTF-8'>

# %%
a = '        인천     정보  산업 HHH   '
a = a.strip()
a = a.lower()
a.split()
# Out:
# ['인천', '정보', '산업', 'hhh']

# %%
a=[3,2,1]
b=[4,5]
a.append(b)
a
# Out:
# [3, 2, 1, [4, 5]]

# %%
a=[3,2,1]
b=[4,5]
a.extend(b)
a
# Out:
# [3, 2, 1, 4, 5]

# %%
prince=[]
for line in file:
  line = line.lower()
  word = line.split()
  line = line.strip()
  prince.extend(word)
print(prince)
# Out:
# ['chapter', 'one', 'once', 'when', 'i', 'was', 'six', 'i', 'saw', 'a', 'magnificent', 'picture', 'in', 'a', 'book', 'about', 'the', 'jungle,', 'called', 'true', 'stories.', 'it', 'showed', 'a', 'boa', 'constrictor', 'swallowing', 'a', 'wild', 'beast.', 'here', 'is', 'a', 'copy', 'of', 'the', 'picture.', 'in', 'the', 'book', 'it', 'said:', '"boa', 'constrictors', 'swallow', 'their', 'prey', 'whole,', 'without', 'chewing.', 'afterward', 'they', 'are', 'no', 'longer', 'able', 'to', 'move,', 'and', 'they', 'sleep', 'for', 'six', 'months', 'they', 'need', 'for', 'digestion."', 'in', 'those', 'days', 'i', 'thought', 'a', 'lot', 'about', 'jungle', 'adventures,', 'and', 'eventually', 'managed', 'to', 'make', 'my', 'first', 'drawing,', 'with', 'a', 'colored', 'pencil.', 'my', 'drawing', 'number', 'one', 'looked', 'like', 'this:', 'i', 'showed', 'the', 'grown-ups', 'my', 'masterpiece,', 'and', 'i', 'asked', 'them', 'if', 'my', 'drawing', 'scared', 'them.', 'they', 'answered,', '"why', 'should'
# ...

# %%
def count(d):
  freq = {}
  for i in d:
    if i not in freq:
      freq[i]=1
    elif i in freq:
      freq[i]+= 1
  return freq

# %%
fr={}
fr['학교']=1
fr
# Out:
# {'학교': 1}

# %%
ㅣp = count(prince)
ㅣp
# Out:
# {'chapter': 27,
#  'one': 85,
#  'once': 16,
#  'when': 50,
#  'i': 342,
#  'was': 155,
#  'six': 11,
#  'saw': 13,
#  'a': 390,
#  'magnificent': 3,
#  'picture': 3,
#  'in': 128,
#  'book': 4,
#  'about': 29,
#  'the': 820,
#  'jungle,': 1,
#  'called': 1,
#  'true': 5,
#  'stories.': 1,
#  'it': 105,
#  'showed': 4,
#  'boa': 11,
#  'constrictor': 4,
#  'swallowing': 1,
#  'wild': 2,
#  'beast.': 1,
#  'here': 12,
#  'is': 98,
#  'copy': 1,
#  'of': 263,
#  'picture.': 1,
#  'said:': 2,
#  '"boa': 1,
#  'constrictors': 2,
#  'swallow': 2,
#  'their': 12,
#  'prey': 1,
#  'whole,': 1,
#  'without': 12,
#  'chewing.': 1,
#  'afterward': 1,
#  'they': 63,
#  'are': 75,
#  'no': 50,
#  'longer': 6,
#  'able': 5,
#  'to': 352,
#  'move,': 1,
#  'and': 306,
#  'sleep': 3,
#  'for': 118,
#  'months': 1,
#  'need': 10,
#  'digestion."': 1,
#  'those': 18,
#  'days': 5,
#  'thought': 8,
#  'lot': 3,
#  'jungle': 1,
#  'adventures,': 1,
#  'eventually': 2,
#  'managed': 4,
#  'make': 22,
# ...
