# %%
a = ['kor','eng','math']
b=[30,100,-80]

# %%
a
# Out:
# ['kor', 'eng', 'math']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.plot(a,b)

# %%
plt.barh(a,b,color='skyblue')
plt.ylabel('subject')
plt.xlabel('score')
plt.title('Level')
# Out:
# Text(0.5, 1.0, 'Level')

# %%
plt.plot(a,b,'g^',color='green')
plt.plot([1,2,3,4,5],[80,50,70,100,90], 'r--',color='skyblue')
plt.xlabel('X name')
plt.ylabel('Y Value')
plt.title('Test')
plt.legend(['A','B'])

# %%
plt.plot(a,b)
plt.plot([1,2,3,4,5],[80,50,70,100,90])
plt.xlabel('X name')
plt.ylabel('Y Value')
plt.title('Test')
plt.legend(['A','B'])

# %%
b
# Out:
# [30, 100, -80]

# %%
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts()

# %%
path = 'C:\\Windows\\Fonts\\HANDotum.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('점수들')
# Out:
# Text(0, 0.5, '점수들')

# %%
import pandas as pd
path = r'C:\Users\user\Desktop\301\\B.csv'
df = pd.read_csv(path,encoding='cp949')
df.head(5)
# Out:
#   출신고교     학번   이름  국어  수학  영어  과탐1  과탐2
# 0    B  30103  곽뱅어  91  50  82   27   37
# 1    B  30122  성붕어  70  32  64   20   25
# 2    B  30130  차우럭  87  77  91   34   28
# 3    B  30204  주잉어  69  44  84   19   24
# 4    B  30205  우뽈락  84  54  54   41   39

# %%
f = df.head(5)
a= f['이름']
b= f['국어']

# %%
a
# Out:
# 0    곽뱅어
# 1    성붕어
# 2    차우럭
# 3    주잉어
# 4    우뽈락
# Name: 이름, dtype: object

# %%
b
# Out:
# 0    91
# 1    70
# 2    87
# 3    69
# 4    84
# Name: 국어, dtype: int64

# %%
plt.plot(a,b,'r--',color='hotpink')
plt.title('국어 성적')
plt.ylabel('성적')
plt.xlabel('이름')
# Out:
# Text(0.5, 0, '이름')
